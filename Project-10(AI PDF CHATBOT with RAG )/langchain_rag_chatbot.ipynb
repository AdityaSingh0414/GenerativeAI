# %%
# !pip install -q --upgrade langchain langchain_google_genai langchain-core langchain_community docs2txt pypdf langchain_chroma sentence_transformers

# %%
# what is retieval Augmented Genration (RAG)?
#Retrieval-Augmented Generation (RAG) is a technique in natural language processing that combines the capabilities of retrieval-based models and generative models to improve the quality and relevance of generated text.

/*components and LangChain Components and Expression Language (LCEL)
# Large Language Model (LLM)
# Output Parsers
# Structured Output
# Prompt Templates
# LLM Messages */

# %%
import os
os.environ["GOOGLE_GENAI_API_KEY"]=""

# %%
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ['LANGCHAIN_API_KEY']=""
os.environ['LANGCHAIN_PROJECT']=''

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=
